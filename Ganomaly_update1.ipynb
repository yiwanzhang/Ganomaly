# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv("MotorRPM_time.csv")

# %%
data.head(5)
# Out:
#                   time  MotorRPM
# 0  2022-08-30 00:00:00  1056.705
# 1  2022-08-30 00:01:00  1056.760
# 2  2022-08-30 00:02:00  1056.815
# 3  2022-08-30 00:03:00  1056.705
# 4  2022-08-30 00:04:00  1056.870

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273962 entries, 0 to 273961
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   time      273962 non-null  object
#  1   MotorRPM  273961 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 4.2+ MB

# %%
data['time'] = pd.to_datetime(data['time'])
data.set_index('time', inplace=True)
data.sort_index(inplace=True)
data = data.resample('D').mean().fillna(method='ffill')
data['MotorRPM'] = MinMaxScaler().fit_transform(data[['MotorRPM']])
data
# Out:
#             MotorRPM
# time
# 2022-08-30  1.000000
# 2022-08-31  0.444015
# 2022-09-01  0.411073
# 2022-09-02  0.411073
# 2022-09-03  0.411073
# ...              ...
# 2023-03-16  0.198645
# 2023-03-17  0.114612
# 2023-03-18  0.114356
# 2023-03-19  0.114720
# 2023-03-20  0.114047
#
# [203 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(data.index, data['MotorRPM']) 
plt.title('Motor RPM Over Time')
plt.xlabel('Date') 
plt.ylabel('Motor RPM (Normalized)') 
plt.grid(True) 
plt.show()

# %%
num_features = data.shape[1]
print('Number of features:', num_features)
# Out:
# Number of features: 1

# %%
# plt.figure(figsize=(10,6))

# # 将日期列转换为datetime格式，以便正确解析
# train['Date'] = pd.to_datetime(test['Date'])

# plt.plot(test['Date'], test['MotorRPM'])
# plt.title('Motor RPM Over Time')
# plt.xlabel('Date')
# plt.ylabel('Motor RPM')
# plt.grid(True)
# plt.show()

# %%
# 划分数据集 Split dataset
train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)
train_tensor = torch.from_numpy(train_data.values.astype(np.float32))
test_tensor = torch.from_numpy(test_data.values.astype(np.float32))

# %%
# 创建数据加载器 Creating a data loader
from torch.utils.data import DataLoader
batch_size = 32
train_loader = DataLoader(train_tensor, batch_size=batch_size, shuffle=True)

# %%
class Generator(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(Generator, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.LeakyReLU(),
        )
        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, input_dim),
            nn.ReLU(),
        )

    def forward(self, x):
        z = self.encoder(x)
        x_hat = self.decoder(z)
        return x_hat

class Discriminator(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.LeakyReLU(),
            nn.Linear(hidden_dim, 1),
            nn.Sigmoid(),
        )

    def forward(self, x):
        return self.model(x)

# 定义损失函数 loss function definition
def fraud_loss(discriminator, real_samples, fake_samples):
    real_samples_loss = nn.BCEWithLogitsLoss()(real_samples_predictions, torch.ones((batch_size, 1)))
    fake_samples_loss = nn.BCEWithLogitsLoss()(fake_samples_predictions, torch.zeros((batch_size, 1)))
    return real_loss + fake_loss

def apparent_loss(generator, real_samples):
    fake_samples = generator(real_samples)
    return torch.mean(torch.abs(real_samples-fake_samples))

# 定义优化器 Optimizer Definition
input_dim = 1 # 输入维度 Input dimension
hidden_dim = 100  # 隐藏层维度 Hidden dimension
generator = Generator(input_dim, hidden_dim)
discriminator = Discriminator(input_dim, hidden_dim)
optimizer_g = optim.Adam(generator.parameters())
optimizer_d = optim.Adam(discriminator.parameters())

# %%
print(generator) #The achitechure of generator
print(discriminator) ##The achitechure of discriminator
# Out:
# Generator(
#   (encoder): Sequential(
#     (0): Linear(in_features=1, out_features=100, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=100, out_features=1, bias=True)
#     (1): ReLU()
#   )
# )
# Discriminator(
#   (model): Sequential(
#     (0): Linear(in_features=1, out_features=100, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=100, out_features=1, bias=True)
#     (3): Sigmoid()
#   )
# )

# %%
# 训练模型 train the model In this training process, the generator tries to generate 
#as realistic samples as possible to deceive the discriminator, while the discriminator tries to classify the real and generated samples.

n_epochs = 300
for epoch in range(n_epochs):
    for i, real_samples in enumerate(train_loader):
        optimizer_g.zero_grad()
        optimizer_d.zero_grad()
        real_samples_labels = torch.ones((batch_size, 1))
        latent_space_samples = torch.randn((batch_size, input_dim))
        generated_samples = generator(latent_space_samples)
        real_samples_predictions = discriminator(real_samples)
        fake_samples_predictions = discriminator(generated_samples)
        
        # Train Discriminator
        real_samples_loss = nn.BCEWithLogitsLoss()(real_samples_predictions, torch.ones_like(real_samples_predictions))
        fake_samples_loss = nn.BCEWithLogitsLoss()(fake_samples_predictions, torch.zeros_like(fake_samples_predictions))
#         real_samples_loss = nn.BCEWithLogitsLoss()(real_samples_predictions, torch.ones_like(real_samples_predictions))
#         fake_samples_loss = nn.BCEWithLogitsLoss()(fake_samples_predictions, torch.zeros_like(fake_samples_predictions))

        discriminator_loss = real_samples_loss + fake_samples_loss

        discriminator_loss.backward()
        optimizer_d.step()

        # Train Generator
        optimizer_g.zero_grad()
        latent_space_samples = torch.randn((batch_size, input_dim))
        generated_samples = generator(latent_space_samples)

        discriminator_output_on_generated = discriminator(generated_samples)
        generator_loss = apparent_loss(generator, real_samples)
        
        generator_loss.backward()
        optimizer_g.step()

    
    print(f"Epoch {epoch} of {n_epochs}")
    print(f"Generator loss: {generator_loss}")
    print(f"Discriminator loss: {discriminator_loss}")
#         generated_samples_labels = torch.zeros((batch_size, 1))
#         real_samples = real_samples.expand(-1, hidden_dim)
#         all_samples = torch.cat((real_samples, generated_samples))
#         all_samples_labels = torch.cat((real_samples_labels, generated_samples_labels))

#         discriminator_output = discriminator(all_samples)
#         discriminator_loss = fraud_loss(discriminator_output, all_samples_labels)
        
#         discriminator_loss.backward()
#         optimizer_d.step()

#         # 2. 训练 Generator
#         latent_space_samples = torch.randn((batch_size, hidden_dim))
#         generated_samples = generator(latent_space_samples)
#         discriminator_output = discriminator(generated_samples)
#         generator_loss = apparent_loss(generator, real_samples)
#         generator_loss.backward()
#         optimizer_g.step()

#     # 显示损失
#     print(f"Epoch {epoch} of {n_epochs}")
#     print(f"Generator loss: {generator_loss}")
#     print(f"Discriminator loss: {discriminator_loss}")
# Out:
# Epoch 0 of 300
# Generator loss: 0.0035138316452503204
# Discriminator loss: 1.0480828285217285
# Epoch 1 of 300
# Generator loss: 0.0020560212433338165
# Discriminator loss: 1.032684564590454
# Epoch 2 of 300
# Generator loss: 0.002138238400220871
# Discriminator loss: 1.059661865234375
# Epoch 3 of 300
# Generator loss: 0.0019932985305786133
# Discriminator loss: 1.0407538414001465
# Epoch 4 of 300
# Generator loss: 0.0032666921615600586
# Discriminator loss: 1.4271020889282227
# Epoch 5 of 300
# Generator loss: 0.002311747521162033
# Discriminator loss: 1.206373691558838
# Epoch 6 of 300
# Generator loss: 0.0015596188604831696
# Discriminator loss: 1.0627317428588867
# Epoch 7 of 300
# Generator loss: 0.007853306829929352
# Discriminator loss: 1.0683670043945312
# Epoch 8 of 300
# Generator loss: 0.0038035064935684204
# Discriminator loss: 1.2589306831359863
# Epoch 9 of 300
# Generator loss: 0.006308756768703461
# Discriminator loss: 1.02070152759552
# Epoch 10 of 300
# Generator loss: 0.0021413639187812805
# Discriminator loss: 1.0545825958251953
# Epoch 11 of 300
# Generator loss: 0.006613023579120636
# Discriminator loss: 1.1014890670776367
# Epoch 12 of 300
# Generator loss: 0.0019624829292297363
# Discriminator loss: 1.0973796844482422
# Epoch 13 of 300
# Generator loss: 0.006224878132343292
# Discriminator loss: 1.029679536819458
# Epoch 14 of 300
# Generator loss: 0.001889694482088089
# Discriminator loss: 1.1182864904403687
# Epoch 15 of 300
# Generator loss: 0.0026422590017318726
# Discriminator loss: 1.0478662252426147
# Epoch 16 of 300
# Generator loss: 0.0026634596288204193
# Discriminator loss: 1.0326533317565918
# Epoch 17 of 300
# Generator loss: 0.00200512632727623
# Discriminator loss: 1.0538487434387207
# Epoch 18 of 300
# Generator loss: 0.0043091438710689545
# Discriminator loss: 1.0922611951828003
# Epoch 19 of 300
# Generator loss: 0.0017348192632198334
# Discriminator loss: 1.1100311279296875
# Epoch 20 of 300
# Generator loss: 0.00260268896818161
# Discriminator loss: 1.0785248279571533
# Epoch 21 of 300
# Generator loss: 0.0031952224671840668
# Discriminator loss: 1.094262957572937
# Epoch 22 of 300
# Generator loss: 0.003238026052713394
# Discriminator loss: 1.0523135662078857
# Epoch 23 of 300
# Generator loss: 0.003643833100795746
# Discriminator loss: 1.028062105178833
# Epoch 24 of 300
# Generator loss: 0.004167262464761734
# Discriminator loss: 1.2510504722595215
# Epoch 25 of 300
# Generator loss: 0.004103496670722961
# Discriminator loss: 1.0809619426727295
# Epoch 26 of 300
# Generator loss: 0.0014013536274433136
# Discriminator loss: 1.0973235368728638
# Epoch 27 of 300
# Generator loss: 0.0012370161712169647
# Discriminator loss: 1.1011030673980713
# Epoch 28 of 300
# Generator loss: 0.0003706738352775574
# Discriminator loss: 1.0701797008514404
# Epoch 29 of 300
# Generator loss: 0.001397881656885147
# Discriminator loss: 1.1089962720870972
# Epoch 30 of 300
# Generator loss: 0.0009711310267448425
# Discriminator loss: 1.084850549697876
# Epoch 31 of 300
# Generator loss: 0.0027470067143440247
# Discriminator loss: 1.304694652557373
# Epoch 32 of 300
# Generator loss: 0.0013739019632339478
# Discriminator loss: 1.1106185913085938
# Epoch 33 of 300
# Generator loss: 0.0013976208865642548
# Discriminator loss: 1.0619397163391113
# Epoch 34 of 300
# Generator loss: 0.0019925497472286224
# Discriminator loss: 1.047134518623352
# Epoch 35 of 300
# Generator loss: 0.001502111554145813
# Discriminator loss: 1.078969955444336
# Epoch 36 of 300
# Generator loss: 0.0013144910335540771
# Discriminator loss: 1.0826303958892822
# Epoch 37 of 300
# Generator loss: 0.0015571974217891693
# Discriminator loss: 1.0599935054779053
# Epoch 38 of 300
# Generator loss: 0.0009990409016609192
# Discriminator loss: 1.0302743911743164
# Epoch 39 of 300
# Generator loss: 0.000922180712223053
# Discriminator loss: 1.0527839660644531
# Epoch 40 of 300
# Generator loss: 0.00013525411486625671
# Discriminator loss: 1.0770684480667114
# Epoch 41 of 300
# Generator loss: 0.0006925798952579498
# Discriminator loss: 1.048443078994751
# Epoch 42 of 300
# Generator loss: 0.00015247613191604614
# Discriminator loss: 1.0446405410766602
# Epoch 43 of 300
# Generator loss: 0.001319289207458496
# Discriminator loss: 1.375474452972412
# Epoch 44 of 300
# Generator loss: 0.001130770891904831
# Discriminator loss: 1.1221964359283447
# Epoch 45 of 300
# Generator loss: 0.0041830651462078094
# Discriminator loss: 1.0865272283554077
# Epoch 46 of 300
# Generator loss: 0.008660044521093369
# Discriminator loss: 1.0335803031921387
# Epoch 47 of 300
# Generator loss: 0.002363353967666626
# Discriminator loss: 1.065258264541626
# Epoch 48 of 300
# Generator loss: 0.001710057258605957
# Discriminator loss: 1.033674716949463
# Epoch 49 of 300
# Generator loss: 0.006431948393583298
# Discriminator loss: 1.059619426727295
# Epoch 50 of 300
# Generator loss: 0.006145104765892029
# Discriminator loss: 1.02034330368042
# Epoch 51 of 300
# Generator loss: 0.0011125653982162476
# Discriminator loss: 1.0296196937561035
# Epoch 52 of 300
# Generator loss: 0.003408074378967285
# Discriminator loss: 1.0858927965164185
# Epoch 53 of 300
# Generator loss: 0.0013837292790412903
# Discriminator loss: 1.1309566497802734
# Epoch 54 of 300
# Generator loss: 0.0019535571336746216
# Discriminator loss: 1.2632262706756592
# Epoch 55 of 300
# Generator loss: 0.0007615648210048676
# Discriminator loss: 1.27381432056427
# Epoch 56 of 300
# Generator loss: 0.002387493848800659
# Discriminator loss: 1.0405595302581787
# Epoch 57 of 300
# Generator loss: 0.0007233582437038422
# Discriminator loss: 1.0514707565307617
# Epoch 58 of 300
# Generator loss: 0.0031332485377788544
# Discriminator loss: 1.1451457738876343
# Epoch 59 of 300
# Generator loss: 0.0010412819683551788
# Discriminator loss: 1.0529201030731201
# Epoch 60 of 300
# Generator loss: 0.0010314173996448517
# Discriminator loss: 1.1029391288757324
# Epoch 61 of 300
# Generator loss: 0.0006236881017684937
# Discriminator loss: 1.0276850461959839
# Epoch 62 of 300
# Generator loss: 0.0023530013859272003
# Discriminator loss: 1.0715062618255615
# Epoch 63 of 300
# Generator loss: 0.0017450079321861267
# Discriminator loss: 1.1065609455108643
# Epoch 64 of 300
# Generator loss: 0.0009099990129470825
# Discriminator loss: 1.1439741849899292
# Epoch 65 of 300
# Generator loss: 0.002226725220680237
# Discriminator loss: 1.0614126920700073
# Epoch 66 of 300
# Generator loss: 0.0020214244723320007
# Discriminator loss: 1.076127052307129
# Epoch 67 of 300
# Generator loss: 0.0006868429481983185
# Discriminator loss: 1.081990361213684
# Epoch 68 of 300
# Generator loss: 0.0007906593382358551
# Discriminator loss: 1.0130627155303955
# Epoch 69 of 300
# Generator loss: 0.00024849921464920044
# Discriminator loss: 1.1878548860549927
# Epoch 70 of 300
# Generator loss: 0.0008529350161552429
# Discriminator loss: 1.0161633491516113
# Epoch 71 of 300
# Generator loss: 0.0012859106063842773
# Discriminator loss: 1.0818744897842407
# Epoch 72 of 300
# Generator loss: 0.003364384174346924
# Discriminator loss: 1.108300805091858
# Epoch 73 of 300
# Generator loss: 0.005399223417043686
# Discriminator loss: 1.0342634916305542
# Epoch 74 of 300
# Generator loss: 0.002149626612663269
# Discriminator loss: 1.2601197957992554
# Epoch 75 of 300
# Generator loss: 0.0011724159121513367
# Discriminator loss: 1.0520991086959839
# Epoch 76 of 300
# Generator loss: 0.0018394067883491516
# Discriminator loss: 1.1494858264923096
# Epoch 77 of 300
# Generator loss: 0.0009532831609249115
# Discriminator loss: 1.0648714303970337
# Epoch 78 of 300
# Generator loss: 0.00048782676458358765
# Discriminator loss: 1.0341839790344238
# Epoch 79 of 300
# Generator loss: 0.0004461333155632019
# Discriminator loss: 1.0871939659118652
# Epoch 80 of 300
# Generator loss: 0.006183501332998276
# Discriminator loss: 1.0257986783981323
# Epoch 81 of 300
# Generator loss: 0.005309801548719406
# Discriminator loss: 1.022435188293457
# Epoch 82 of 300
# Generator loss: 0.0004904083907604218
# Discriminator loss: 1.0295367240905762
# Epoch 83 of 300
# Generator loss: 0.0007744394242763519
# Discriminator loss: 1.0723834037780762
# Epoch 84 of 300
# Generator loss: 0.0013330206274986267
# Discriminator loss: 1.058431625366211
# Epoch 85 of 300
# Generator loss: 0.0005289614200592041
# Discriminator loss: 1.0770213603973389
# Epoch 86 of 300
# Generator loss: 0.002674642950296402
# Discriminator loss: 1.0716499090194702
# Epoch 87 of 300
# Generator loss: 0.0019491836428642273
# Discriminator loss: 1.0633201599121094
# Epoch 88 of 300
# Generator loss: 0.000270601361989975
# Discriminator loss: 1.2574867010116577
# Epoch 89 of 300
# Generator loss: 0.0013583190739154816
# Discriminator loss: 1.1218867301940918
# Epoch 90 of 300
# Generator loss: 0.007455404847860336
# Discriminator loss: 1.0343377590179443
# Epoch 91 of 300
# Generator loss: 0.0030834265053272247
# Discriminator loss: 1.0528082847595215
# Epoch 92 of 300
# Generator loss: 0.008500605821609497
# Discriminator loss: 1.0743868350982666
# Epoch 93 of 300
# Generator loss: 0.0014054365456104279
# Discriminator loss: 1.0634844303131104
# Epoch 94 of 300
# Generator loss: 0.0003094598650932312
# Discriminator loss: 1.0923192501068115
# Epoch 95 of 300
# Generator loss: 0.0030480585992336273
# Discriminator loss: 1.0380305051803589
# Epoch 96 of 300
# Generator loss: 0.0029366351664066315
# Discriminator loss: 1.0480270385742188
# Epoch 97 of 300
# Generator loss: 0.0025652237236499786
# Discriminator loss: 1.0716886520385742
# Epoch 98 of 300
# Generator loss: 0.0016356110572814941
# Discriminator loss: 1.0498456954956055
# Epoch 99 of 300
# Generator loss: 0.0008381307125091553
# Discriminator loss: 1.4367032051086426
# Epoch 100 of 300
# Generator loss: 0.0008207894861698151
# Discriminator loss: 1.1325676441192627
# Epoch 101 of 300
# Generator loss: 0.0011561326682567596
# Discriminator loss: 1.1018776893615723
# Epoch 102 of 300
# Generator loss: 0.003792133182287216
# Discriminator loss: 1.13407564163208
# Epoch 103 of 300
# Generator loss: 0.002362474799156189
# Discriminator loss: 1.0829315185546875
# Epoch 104 of 300
# Generator loss: 0.005268361419439316
# Discriminator loss: 1.0587230920791626
# Epoch 105 of 300
# Generator loss: 0.007624760270118713
# Discriminator loss: 1.0590827465057373
# Epoch 106 of 300
# Generator loss: 0.0018888041377067566
# Discriminator loss: 1.0175150632858276
# Epoch 107 of 300
# Generator loss: 0.0020920224487781525
# Discriminator loss: 1.0903654098510742
# Epoch 108 of 300
# Generator loss: 0.005483150482177734
# Discriminator loss: 1.0406494140625
# Epoch 109 of 300
# Generator loss: 0.004690360277891159
# Discriminator loss: 1.0162267684936523
# Epoch 110 of 300
# Generator loss: 0.0033689066767692566
# Discriminator loss: 1.0655827522277832
# Epoch 111 of 300
# Generator loss: 0.006099123507738113
# Discriminator loss: 1.0423049926757812
# Epoch 112 of 300
# Generator loss: 0.006097257137298584
# Discriminator loss: 1.0668827295303345
# Epoch 113 of 300
# Generator loss: 0.005464326590299606
# Discriminator loss: 1.0111435651779175
# Epoch 114 of 300
# Generator loss: 0.003777753561735153
# Discriminator loss: 1.0322508811950684
# Epoch 115 of 300
# Generator loss: 0.00753156840801239
# Discriminator loss: 1.2922979593276978
# Epoch 116 of 300
# Generator loss: 0.004179276525974274
# Discriminator loss: 1.3089954853057861
# Epoch 117 of 300
# Generator loss: 0.004238273948431015
# Discriminator loss: 1.0270609855651855
# Epoch 118 of 300
# Generator loss: 0.0019155219197273254
# Discriminator loss: 1.0478190183639526
# Epoch 119 of 300
# Generator loss: 0.0038738176226615906
# Discriminator loss: 1.0412752628326416
# Epoch 120 of 300
# Generator loss: 0.0006541647017002106
# Discriminator loss: 1.1046924591064453
# Epoch 121 of 300
# Generator loss: 0.004263460636138916
# Discriminator loss: 1.0654176473617554
# Epoch 122 of 300
# Generator loss: 0.002139858901500702
# Discriminator loss: 1.0488104820251465
# Epoch 123 of 300
# Generator loss: 0.0007926560938358307
# Discriminator loss: 1.2737135887145996
# Epoch 124 of 300
# Generator loss: 0.0013328604400157928
# Discriminator loss: 1.0942797660827637
# Epoch 125 of 300
# Generator loss: 0.008866120129823685
# Discriminator loss: 1.0419397354125977
# Epoch 126 of 300
# Generator loss: 0.0009569115936756134
# Discriminator loss: 1.0622057914733887
# Epoch 127 of 300
# Generator loss: 0.00014842301607131958
# Discriminator loss: 1.0465071201324463
# Epoch 128 of 300
# Generator loss: 0.006558679044246674
# Discriminator loss: 1.0441104173660278
# Epoch 129 of 300
# Generator loss: 0.0026280879974365234
# Discriminator loss: 1.0394105911254883
# Epoch 130 of 300
# Generator loss: 0.0072612464427948
# Discriminator loss: 1.0605928897857666
# Epoch 131 of 300
# Generator loss: 0.0011284872889518738
# Discriminator loss: 1.2491235733032227
# Epoch 132 of 300
# Generator loss: 0.004925701767206192
# Discriminator loss: 1.0668280124664307
# Epoch 133 of 300
# Generator loss: 0.00040021538734436035
# Discriminator loss: 1.0807886123657227
# Epoch 134 of 300
# Generator loss: 0.00682300329208374
# Discriminator loss: 1.0317250490188599
# Epoch 135 of 300
# Generator loss: 0.007866822183132172
# Discriminator loss: 1.0397891998291016
# Epoch 136 of 300
# Generator loss: 0.009862713515758514
# Discriminator loss: 1.1036787033081055
# Epoch 137 of 300
# Generator loss: 0.009285993874073029
# Discriminator loss: 1.2611004114151
# Epoch 138 of 300
# Generator loss: 0.00047279149293899536
# Discriminator loss: 1.083390235900879
# Epoch 139 of 300
# Generator loss: 0.0034268684685230255
# Discriminator loss: 1.087361454963684
# Epoch 140 of 300
# Generator loss: 0.01120692864060402
# Discriminator loss: 1.0708062648773193
# Epoch 141 of 300
# Generator loss: 0.006623115390539169
# Discriminator loss: 1.0518643856048584
# Epoch 142 of 300
# Generator loss: 0.0007616989314556122
# Discriminator loss: 1.0764881372451782
# Epoch 143 of 300
# Generator loss: 0.0012493394315242767
# Discriminator loss: 1.0721144676208496
# Epoch 144 of 300
# Generator loss: 0.0017024986445903778
# Discriminator loss: 1.0630931854248047
# Epoch 145 of 300
# Generator loss: 0.00036602839827537537
# Discriminator loss: 1.0686311721801758
# Epoch 146 of 300
# Generator loss: 0.0002443157136440277
# Discriminator loss: 1.2660220861434937
# Epoch 147 of 300
# Generator loss: 0.0019430965185165405
# Discriminator loss: 1.0457082986831665
# Epoch 148 of 300
# Generator loss: 0.0011881403625011444
# Discriminator loss: 1.0761816501617432
# Epoch 149 of 300
# Generator loss: 0.002574138343334198
# Discriminator loss: 1.067472219467163
# Epoch 150 of 300
# Generator loss: 0.00014813989400863647
# Discriminator loss: 1.027963399887085
# Epoch 151 of 300
# Generator loss: 0.00625542551279068
# Discriminator loss: 1.2331165075302124
# Epoch 152 of 300
# Generator loss: 0.006212390959262848
# Discriminator loss: 1.0444289445877075
# Epoch 153 of 300
# Generator loss: 0.00041869282722473145
# Discriminator loss: 1.0219467878341675
# Epoch 154 of 300
# Generator loss: 0.00573701411485672
# Discriminator loss: 1.0345163345336914
# Epoch 155 of 300
# Generator loss: 0.0018572919070720673
# Discriminator loss: 1.1153024435043335
# Epoch 156 of 300
# Generator loss: 0.004254922270774841
# Discriminator loss: 1.2524564266204834
# Epoch 157 of 300
# Generator loss: 0.0009809508919715881
# Discriminator loss: 1.096535325050354
# Epoch 158 of 300
# Generator loss: 0.006893038749694824
# Discriminator loss: 1.044789433479309
# Epoch 159 of 300
# Generator loss: 0.006921965628862381
# Discriminator loss: 1.2468457221984863
# Epoch 160 of 300
# Generator loss: 0.010104954242706299
# Discriminator loss: 1.199716567993164
# Epoch 161 of 300
# Generator loss: 0.0032400451600551605
# Discriminator loss: 1.043831467628479
# Epoch 162 of 300
# Generator loss: 0.002688217908143997
# Discriminator loss: 1.0835976600646973
# Epoch 163 of 300
# Generator loss: 0.001814715564250946
# Discriminator loss: 1.2622638940811157
# Epoch 164 of 300
# Generator loss: 0.00153438001871109
# Discriminator loss: 1.0911813974380493
# Epoch 165 of 300
# Generator loss: 0.0031942129135131836
# Discriminator loss: 1.0718111991882324
# Epoch 166 of 300
# Generator loss: 0.0039807818830013275
# Discriminator loss: 1.0344291925430298
# Epoch 167 of 300
# Generator loss: 0.0024972036480903625
# Discriminator loss: 1.0251774787902832
# Epoch 168 of 300
# Generator loss: 0.0009472258388996124
# Discriminator loss: 1.0822561979293823
# Epoch 169 of 300
# Generator loss: 0.001948188990354538
# Discriminator loss: 1.0671231746673584
# Epoch 170 of 300
# Generator loss: 0.0014358721673488617
# Discriminator loss: 1.1138743162155151
# Epoch 171 of 300
# Generator loss: 0.0012551695108413696
# Discriminator loss: 1.4240291118621826
# Epoch 172 of 300
# Generator loss: 0.00011818110942840576
# Discriminator loss: 1.0989253520965576
# Epoch 173 of 300
# Generator loss: 0.0013653561472892761
# Discriminator loss: 1.0406408309936523
# Epoch 174 of 300
# Generator loss: 0.0016982704401016235
# Discriminator loss: 1.0509188175201416
# Epoch 175 of 300
# Generator loss: 0.0004205666482448578
# Discriminator loss: 1.1471549272537231
# Epoch 176 of 300
# Generator loss: 0.0007731914520263672
# Discriminator loss: 1.055454134941101
# Epoch 177 of 300
# Generator loss: 0.0003611519932746887
# Discriminator loss: 1.0112919807434082
# Epoch 178 of 300
# Generator loss: 0.0017570070922374725
# Discriminator loss: 1.113142490386963
# Epoch 179 of 300
# Generator loss: 0.0038113296031951904
# Discriminator loss: 1.2437031269073486
# Epoch 180 of 300
# Generator loss: 0.006653256714344025
# Discriminator loss: 1.0746304988861084
# Epoch 181 of 300
# Generator loss: 0.004168160259723663
# Discriminator loss: 1.0374741554260254
# Epoch 182 of 300
# Generator loss: 0.00535241886973381
# Discriminator loss: 1.0664676427841187
# Epoch 183 of 300
# Generator loss: 0.002911228686571121
# Discriminator loss: 1.0954397916793823
# Epoch 184 of 300
# Generator loss: 0.002576783299446106
# Discriminator loss: 1.0450482368469238
# Epoch 185 of 300
# Generator loss: 0.0010928548872470856
# Discriminator loss: 1.0644760131835938
# Epoch 186 of 300
# Generator loss: 0.0030001476407051086
# Discriminator loss: 1.2418339252471924
# Epoch 187 of 300
# Generator loss: 0.0037968382239341736
# Discriminator loss: 1.0495444536209106
# Epoch 188 of 300
# Generator loss: 0.0029583871364593506
# Discriminator loss: 1.0555534362792969
# Epoch 189 of 300
# Generator loss: 0.005400180816650391
# Discriminator loss: 1.0363795757293701
# Epoch 190 of 300
# Generator loss: 0.0013006441295146942
# Discriminator loss: 1.0301424264907837
# Epoch 191 of 300
# Generator loss: 0.006664149463176727
# Discriminator loss: 1.2058637142181396
# Epoch 192 of 300
# Generator loss: 0.0015925467014312744
# Discriminator loss: 1.2581430673599243
# Epoch 193 of 300
# Generator loss: 0.0005216412246227264
# Discriminator loss: 1.0142171382904053
# Epoch 194 of 300
# Generator loss: 0.0030644647777080536
# Discriminator loss: 1.0493388175964355
# Epoch 195 of 300
# Generator loss: 0.004447337239980698
# Discriminator loss: 1.0463104248046875
# Epoch 196 of 300
# Generator loss: 0.003662124276161194
# Discriminator loss: 1.0341241359710693
# Epoch 197 of 300
# Generator loss: 0.004551205784082413
# Discriminator loss: 1.0436229705810547
# Epoch 198 of 300
# Generator loss: 0.0035026147961616516
# Discriminator loss: 1.0187392234802246
# Epoch 199 of 300
# Generator loss: 0.005215533077716827
# Discriminator loss: 1.028509259223938
# Epoch 200 of 300
# Generator loss: 0.003035031259059906
# Discriminator loss: 1.0359117984771729
# Epoch 201 of 300
# Generator loss: 0.007008913904428482
# Discriminator loss: 1.0415639877319336
# Epoch 202 of 300
# Generator loss: 0.0019379258155822754
# Discriminator loss: 1.0457589626312256
# Epoch 203 of 300
# Generator loss: 0.0007692165672779083
# Discriminator loss: 1.1901787519454956
# Epoch 204 of 300
# Generator loss: 0.000364501029253006
# Discriminator loss: 1.0681098699569702
# Epoch 205 of 300
# Generator loss: 0.008522618561983109
# Discriminator loss: 1.2349108457565308
# Epoch 206 of 300
# Generator loss: 0.0021721161901950836
# Discriminator loss: 1.0703952312469482
# Epoch 207 of 300
# Generator loss: 0.008946940302848816
# Discriminator loss: 1.4325270652770996
# Epoch 208 of 300
# Generator loss: 0.003616597503423691
# Discriminator loss: 1.02961266040802
# Epoch 209 of 300
# Generator loss: 0.005849111825227737
# Discriminator loss: 1.0301589965820312
# Epoch 210 of 300
# Generator loss: 0.0035323873162269592
# Discriminator loss: 1.2164844274520874
# Epoch 211 of 300
# Generator loss: 0.0016706623136997223
# Discriminator loss: 1.036820888519287
# Epoch 212 of 300
# Generator loss: 0.003363054245710373
# Discriminator loss: 1.0732251405715942
# Epoch 213 of 300
# Generator loss: 0.0013806261122226715
# Discriminator loss: 1.0600107908248901
# Epoch 214 of 300
# Generator loss: 0.005075760185718536
# Discriminator loss: 1.342229962348938
# Epoch 215 of 300
# Generator loss: 0.0006168819963932037
# Discriminator loss: 1.0942680835723877
# Epoch 216 of 300
# Generator loss: 0.008763737976551056
# Discriminator loss: 1.075026273727417
# Epoch 217 of 300
# Generator loss: 0.0017352253198623657
# Discriminator loss: 1.0109893083572388
# Epoch 218 of 300
# Generator loss: 0.00286995992064476
# Discriminator loss: 1.24241304397583
# Epoch 219 of 300
# Generator loss: 0.0016888491809368134
# Discriminator loss: 1.0561305284500122
# Epoch 220 of 300
# Generator loss: 0.0011724866926670074
# Discriminator loss: 1.1047747135162354
# Epoch 221 of 300
# Generator loss: 0.004020258784294128
# Discriminator loss: 1.2765169143676758
# Epoch 222 of 300
# Generator loss: 0.0015810169279575348
# Discriminator loss: 1.0810997486114502
# Epoch 223 of 300
# Generator loss: 0.005164142698049545
# Discriminator loss: 1.284266471862793
# Epoch 224 of 300
# Generator loss: 0.00846131145954132
# Discriminator loss: 1.2980024814605713
# Epoch 225 of 300
# Generator loss: 0.0014847517013549805
# Discriminator loss: 1.146385908126831
# Epoch 226 of 300
# Generator loss: 0.00042596831917762756
# Discriminator loss: 1.0448529720306396
# Epoch 227 of 300
# Generator loss: 0.006384614855051041
# Discriminator loss: 1.0520468950271606
# Epoch 228 of 300
# Generator loss: 0.004152856767177582
# Discriminator loss: 1.072092056274414
# Epoch 229 of 300
# Generator loss: 0.002840980887413025
# Discriminator loss: 1.216828465461731
# Epoch 230 of 300
# Generator loss: 0.0032273530960083008
# Discriminator loss: 1.0462086200714111
# Epoch 231 of 300
# Generator loss: 0.0013556964695453644
# Discriminator loss: 1.2003412246704102
# Epoch 232 of 300
# Generator loss: 0.0011494755744934082
# Discriminator loss: 1.2122077941894531
# Epoch 233 of 300
# Generator loss: 0.0009079016745090485
# Discriminator loss: 1.028538465499878
# Epoch 234 of 300
# Generator loss: 0.0007985606789588928
# Discriminator loss: 1.0179405212402344
# Epoch 235 of 300
# Generator loss: 0.0008516125380992889
# Discriminator loss: 1.226647973060608
# Epoch 236 of 300
# Generator loss: 0.0044771768152713776
# Discriminator loss: 1.0519328117370605
# Epoch 237 of 300
# Generator loss: 0.00108366459608078
# Discriminator loss: 1.0405800342559814
# Epoch 238 of 300
# Generator loss: 0.0051279328763484955
# Discriminator loss: 1.0352104902267456
# Epoch 239 of 300
# Generator loss: 0.004349593073129654
# Discriminator loss: 1.0266385078430176
# Epoch 240 of 300
# Generator loss: 0.0048807114362716675
# Discriminator loss: 1.0329983234405518
# Epoch 241 of 300
# Generator loss: 0.004587974399328232
# Discriminator loss: 1.060746669769287
# Epoch 242 of 300
# Generator loss: 0.0018745921552181244
# Discriminator loss: 1.05613374710083
# Epoch 243 of 300
# Generator loss: 0.002716153860092163
# Discriminator loss: 1.2356655597686768
# Epoch 244 of 300
# Generator loss: 0.0024426504969596863
# Discriminator loss: 1.0392251014709473
# Epoch 245 of 300
# Generator loss: 0.006427355110645294
# Discriminator loss: 1.0654367208480835
# Epoch 246 of 300
# Generator loss: 0.006050493568181992
# Discriminator loss: 1.1379587650299072
# Epoch 247 of 300
# Generator loss: 0.0033144764602184296
# Discriminator loss: 1.0966700315475464
# Epoch 248 of 300
# Generator loss: 0.006266899406909943
# Discriminator loss: 1.0509822368621826
# Epoch 249 of 300
# Generator loss: 0.008437592536211014
# Discriminator loss: 1.0708255767822266
# Epoch 250 of 300
# Generator loss: 0.009237539023160934
# Discriminator loss: 1.0637457370758057
# Epoch 251 of 300
# Generator loss: 0.00858147069811821
# Discriminator loss: 1.1010607481002808
# Epoch 252 of 300
# Generator loss: 0.001677144318819046
# Discriminator loss: 1.2176694869995117
# Epoch 253 of 300
# Generator loss: 0.0012614242732524872
# Discriminator loss: 1.2409663200378418
# Epoch 254 of 300
# Generator loss: 0.004516255110502243
# Discriminator loss: 1.0613954067230225
# Epoch 255 of 300
# Generator loss: 0.0009212270379066467
# Discriminator loss: 1.0121021270751953
# Epoch 256 of 300
# Generator loss: 0.0008621327579021454
# Discriminator loss: 1.0128308534622192
# Epoch 257 of 300
# Generator loss: 0.0018725916743278503
# Discriminator loss: 1.0322725772857666
# Epoch 258 of 300
# Generator loss: 0.0006614252924919128
# Discriminator loss: 1.2126020193099976
# Epoch 259 of 300
# Generator loss: 0.0002957247197628021
# Discriminator loss: 1.2584785223007202
# Epoch 260 of 300
# Generator loss: 0.0013007260859012604
# Discriminator loss: 1.0313352346420288
# Epoch 261 of 300
# Generator loss: 0.001165580004453659
# Discriminator loss: 1.2498698234558105
# Epoch 262 of 300
# Generator loss: 0.0032359622418880463
# Discriminator loss: 1.1340930461883545
# Epoch 263 of 300
# Generator loss: 0.0016354657709598541
# Discriminator loss: 1.0385494232177734
# Epoch 264 of 300
# Generator loss: 0.003991942852735519
# Discriminator loss: 1.0810959339141846
# Epoch 265 of 300
# Generator loss: 0.00023278966546058655
# Discriminator loss: 1.0320348739624023
# Epoch 266 of 300
# Generator loss: 0.0005418434739112854
# Discriminator loss: 1.0458213090896606
# Epoch 267 of 300
# Generator loss: 0.0008930973708629608
# Discriminator loss: 1.2342838048934937
# Epoch 268 of 300
# Generator loss: 0.0010187812149524689
# Discriminator loss: 1.0397601127624512
# Epoch 269 of 300
# Generator loss: 0.00012505054473876953
# Discriminator loss: 1.0254929065704346
# Epoch 270 of 300
# Generator loss: 0.006673865020275116
# Discriminator loss: 1.042922019958496
# Epoch 271 of 300
# Generator loss: 0.0004714168608188629
# Discriminator loss: 1.021140456199646
# Epoch 272 of 300
# Generator loss: 0.003950141370296478
# Discriminator loss: 1.2641196250915527
# Epoch 273 of 300
# Generator loss: 0.0019383281469345093
# Discriminator loss: 1.0335795879364014
# Epoch 274 of 300
# Generator loss: 0.003116130828857422
# Discriminator loss: 1.0098295211791992
# Epoch 275 of 300
# Generator loss: 0.0009990409016609192
# Discriminator loss: 1.071508765220642
# Epoch 276 of 300
# Generator loss: 0.003021959215402603
# Discriminator loss: 1.0509620904922485
# Epoch 277 of 300
# Generator loss: 0.002027839422225952
# Discriminator loss: 1.2940746545791626
# Epoch 278 of 300
# Generator loss: 0.004438314586877823
# Discriminator loss: 1.2802927494049072
# Epoch 279 of 300
# Generator loss: 0.001376122236251831
# Discriminator loss: 1.0621675252914429
# Epoch 280 of 300
# Generator loss: 0.0013823062181472778
# Discriminator loss: 1.1722323894500732
# Epoch 281 of 300
# Generator loss: 0.004045367240905762
# Discriminator loss: 1.0540802478790283
# Epoch 282 of 300
# Generator loss: 0.0041005052626132965
# Discriminator loss: 1.1300405263900757
# Epoch 283 of 300
# Generator loss: 0.005556438118219376
# Discriminator loss: 1.0493223667144775
# Epoch 284 of 300
# Generator loss: 0.0012486986815929413
# Discriminator loss: 1.0670185089111328
# Epoch 285 of 300
# Generator loss: 0.004204984754323959
# Discriminator loss: 1.0350589752197266
# Epoch 286 of 300
# Generator loss: 0.002524465322494507
# Discriminator loss: 1.0322209596633911
# Epoch 287 of 300
# Generator loss: 0.005704082548618317
# Discriminator loss: 1.0690324306488037
# Epoch 288 of 300
# Generator loss: 0.0034012198448181152
# Discriminator loss: 1.166861891746521
# Epoch 289 of 300
# Generator loss: 0.006457306444644928
# Discriminator loss: 1.065926194190979
# Epoch 290 of 300
# Generator loss: 0.009999457746744156
# Discriminator loss: 1.2221518754959106
# Epoch 291 of 300
# Generator loss: 0.00611858069896698
# Discriminator loss: 1.0237488746643066
# Epoch 292 of 300
# Generator loss: 0.0027372129261493683
# Discriminator loss: 1.019980788230896
# Epoch 293 of 300
# Generator loss: 0.00011552870273590088
# Discriminator loss: 1.0849156379699707
# Epoch 294 of 300
# Generator loss: 0.003952160477638245
# Discriminator loss: 1.2697871923446655
# Epoch 295 of 300
# Generator loss: 0.006681378930807114
# Discriminator loss: 1.071757435798645
# Epoch 296 of 300
# Generator loss: 0.0034062154591083527
# Discriminator loss: 1.0088335275650024
# Epoch 297 of 300
# Generator loss: 0.0009683184325695038
# Discriminator loss: 1.0160194635391235
# Epoch 298 of 300
# Generator loss: 0.004163909703493118
# Discriminator loss: 1.0571784973144531
# Epoch 299 of 300
# Generator loss: 0.0028954073786735535
# Discriminator loss: 1.0547900199890137

# %%
# 生成一些随机噪声样本
# Generate some random samples
num_samples = 1000
random_noise = torch.randn(num_samples, input_dim)

# 使用生成器生成假样本
# Generating fake samples using generators

with torch.no_grad():
    generated_samples = generator(random_noise)

# 将生成的样本转换为numpy数组
# Convert the generated samples to numpy arrays
generated_samples = generated_samples.detach().numpy()

# 计算真实样本和生成样本的统计量
# Calculating statistics for real and generated samples
real_mean = real_samples.mean()
real_std = real_samples.std()
gen_mean = generated_samples.mean()
gen_std = generated_samples.std()

print(f"Real mean: {real_mean}, std: {real_std}")
print(f"Generated mean: {gen_mean}, std: {gen_std}")
# The result is not that good ,need to update
# Out:
# Real mean: 0.1455322653055191, std: 0.04178546741604805
# Generated mean: 0.407503217458725, std: 0.6118403673171997

# %%
print(generated_samples.shape)
print(real_samples.shape)
# Out:
# (1000, 1)
# torch.Size([2, 1])

# %%
# 生成一些样本
# Generate some samples
latent_space_samples = torch.randn((len(data), input_dim))
generated_samples = generator(latent_space_samples).detach().numpy()

# 可视化生成的样本与真实样本的比较
# Comparison of visually generated samples with real samples
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['MotorRPM'], label='Real Samples')
plt.plot(data.index, generated_samples, label='Generated Samples')
plt.title('Real Samples vs Generated Samples')
plt.xlabel('Date')
plt.ylabel('Motor RPM (Normalized)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# class generator(nn.Module):
#     def __init__(self,input_size,act_fun,deep=False):
#     super(generator,self).__init__()

#     #deeper neural network or not?
#       if not deep:
#         hidden_size=input_size//2

#         self.encoder_1=nn.Sequential(
#           nn.Linear(input_size,hidden_size),
#           act_fun
#           )

#         self.decoder_1=nn.Sequential(
#           nn.Linear(hidden_size,input_size)
#           )

#         self.encoder_2=nn.Sequential(
#           nn.Linear(input_size,hidden_size),
#           act_fun
#           )
      
#       elif deep:
#         hidden_size_1=input_size//2
#         hidden_size_2=hidden_size_1//2

#         self.encoder_1=nn.Sequential(
#           nn.Linear(input_size,hidden_size_1),
#           act_fun,
#           nn.Linear(hidden_size_1,hidden_size_2),
#           act_fun
#           )

#         self.decoder_1=nn.Sequential(
#           nn.Linear(hidden_size_2,hidden_size_1),
#           act_fun,
#           nn.Linear(hidden_size_1,input_size)
#           )

#         self.encoder_2=nn.Sequential(
#           nn.Linear(input_size,hidden_size_1),
#           act_fun,
#           nn.Linear(hidden_size_1,hidden_size_2),
#           act_fun
#           )

#     def forward(self,input):
#         z=self.encoder_1(input)
#         X_hat=self.decoder_1(z)
#         z_hat=self.encoder_2(X_hat)
#          return z,X_hat,z_hat

# %%
# class Encoder(nn.Module):
#     def __init__(self, input_dim, output_dim):
#         super(Encoder, self).__init__()
#         self.conv = nn.Conv1d(input_dim, output_dim, kernel_size=1)
#         self.batch_norm = nn.BatchNorm1d(output_dim)
#         self.leaky_relu = nn.LeakyReLU()

#     def forward(self, x):
#         x = self.conv(x)
#         x = self.batch_norm(x)
#         x = self.leaky_relu(x)
#         return x

# class Decoder(nn.Module):
#     def __init__(self, input_dim, output_dim):
#         super(Decoder, self).__init__()
#         self.convt = nn.ConvTranspose1d(input_dim, output_dim, kernel_size=1)
#         self.batch_norm = nn.BatchNorm1d(output_dim)
#         self.relu = nn.ReLU()

#     def forward(self, x):
#         x = self.convt(x)
#         x = self.batch_norm(x)
#         x = self.relu(x)
#         return x

# class Generator(nn.Module):
#     def __init__(self, input_dim, latent_dim):
#         super(Generator, self).__init__()
#         self.encoder = Encoder(input_dim, latent_dim)
#         self.decoder = Decoder(latent_dim, input_dim)

#     def forward(self, x):
#         z = self.encoder(x)
#         f_hat = self.decoder(z)
#         return f_hat

# class Discriminator(nn.Module):
#     def __init__(self, input_dim, hidden_dim):
#         super(Discriminator, self).__init__()
#         self.disc = nn.Sequential(
#             nn.Conv2d(input_dim, hidden_dim, kernel_size=3, stride=2, padding=1),
#             nn.BatchNorm2d(hidden_dim),
#             nn.LeakyReLU(),
#             # 更多的层...
#             nn.Conv2d(hidden_dim, 1, kernel_size=3, stride=2, padding=1),
#             nn.Sigmoid()
#         )

#     def forward(self, x):
#         return self.disc(x)
    
# generator = Generator(input_dim, latent_dim)
# discriminator = Discriminator(input_dim, hidden_dim)
# input_dim = # 需要根据你的数据设定
# latent_dim = # 需要根据你的模型设定
# hidden_dim = # 需要根据你的模型设定

# def fraud_loss(real_output, fake_output):
#     return nn.BCEWithLogitsLoss()(fake_output, torch.ones_like(fake_output))

# def apparent_loss(real_output, fake_output):
#     return torch.mean(torch.abs(real_output-fake_output))

# def latent_loss(real_output, fake_output):
#     return torch.mean((real_output - fake_output)**2)
# Out:
#   File "C:\Users\ZHANG YIWAN\AppData\Local\Temp\ipykernel_3208\1451764082.py", line 55
#     input_dim = # 需要根据你的数据设定
#                 ^
# SyntaxError: invalid syntax
